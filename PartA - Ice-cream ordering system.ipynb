# %%
##ICT702                                      ##Task 2  ##Part A                         ##sukhwinder Kaur   ##ID -1117328

##Initialising values
custName = ""
iceNum = 0
iceCount = 0
scoopNum =0
scoopCount=0
topNum=0
topCount = 0 
baseType = 0
scoopType=0
topType = 0
totalCost = 0

icecreamlist = []

##Product type
#tuples to store the type of products
bases = ("List of bases:","cup","plain","waffle")
flavours = ("List of flavours:","vanila","strawberry","chocolate","caramel","mint","rainbow","coffee","bubble gum")
toppings = ("List of toppings:","peanuts","caramel_sauce","rainbow_sprinkles","pecan","chocolate_sprinkles")

##Dictionaries to store the cost of products
baseCost = {"cup":1,"plain":1.5,"waffle":2}
toppingCost = {"peanuts":.75,"caramel_sauce":0.5,"rainbow_sprinkles":0.5,"pecan":1,"chocolate_sprinkles":0.5}
scoopCost = 0.5

#ask for the customer’s name to personalise and track the order.

while custName is "":
    custName = input("Welcome to Below Zero Ice-cream Store. Please Share Your Good Name: ")
if custName is not "":
    print("Hi", custName)

iceNum = int(input("How many ice-creams do you want?"))
while iceNum<=0:
    print("oops!Looks like you do not want any ice-cream.\n")
    iceNum = int(input("How many ice-creams do you want?")) 
    
##Loop through each ice cream,statrting with the base type

while iceNum != iceCount:
    iceCount = iceCount+1
    
    ##Display the current ice cream number
    print("For icecream:", iceCount)
    icecreamlist.append(int(iceCount))
        
    ##Get the ice-cream base type from the customer.
    baseType = int(input("What type of base you want for your ice-cream? cup(1),plain(2) or waffle(3)\n"))
    
    ##if the ice-cream base type is not in 1,2 or 3 then display an error message
    while baseType not in[1,2,3]:
        print("You must choose either option 1,2 or 3")
        baseType = int(input("What type of base you want for your ice-cream? cup(1),plain(2) or waffle(3)\n"))
        print("Thank you")
        
    ##get the totalincluding base type
    totalCost = totalCost+(baseCost.get(bases[baseType]))
    print("$" +str(totalCost))
        
    scoopCount=0
    ##Get scoop number from the customer.
    scoopNum = int(input("How many scoops would you like?\n"))
    
    while scoopNum<=0:
        print("Please choose atleast one scoop.\n")
        scoopNum = int(input("How many scoops would you like?\n"))
    while scoopNum>3:
        print("Sorry!You can take maximum 3 scoops for an ice-cream.\n")
        scoopNum = int(input("How many scoops would you like?\n"))
        
    while scoopNum != scoopCount:
        scoopCount = scoopCount+1
        
        ##Display the current scoop number
        print("For Scoop:" , scoopCount)
        
        ## get the scoop flavour from the customer
        scoopType = int(input("Which flavour would you like:vanila(1),strawberry(2),chocolate(3),caramel(4),mint(5),rainbow(6),coffee(7),bubble gum(8)\n"))
        
        ##update total cost to include scoop type
        totalCost = totalCost+scoopCost
        print("$" +str(totalCost))
        
    topCount = 0    
    ##get toppings from the customer
    topNum = int(input("How many toppings would you like to have?\n"))
        
    while topNum<=0:
        print("Invalid topping")
        topNum = int(input("How many toppings would you like to have?\n"))
    while topNum>4:
        print("Sorry!You can take maximum 4 toppings for an ice-cream.\n")
        topNum = int(input("How many toppings would you like to have?\n"))
    while topNum != topCount:
        topCount = topCount+1
        
        ##Display the current topping numbers
        print("For topping:",topCount)
       
        ##get the topping choice from the customer
        topType =int(input("Whice topping would you like:peanuts(1),caramal_souce(2),rainbow_sprinkles(3),peacan(4),chocolate_sprinkles(5)\n"))
        
        totalCost = totalCost+(toppingCost.get(toppings[topType]))
    print("Total icecreams:"+str(icecreamlist))
    print("Total cost $" +str(totalCost))
    print("Thanku.Have a nice day!")
# Out:
# Welcome to Below Zero Ice-cream Store. Please Share Your Good Name: Sukh
# Hi Sukh
# How many ice-creams do you want?3
# For icecream: 1
# What type of base you want for your ice-cream? cup(1),plain(2) or waffle(3)
# 3
# $2
# How many scoops would you like?
# 4
# Sorry!You can take maximum 3 scoops for an ice-cream.
#
# How many scoops would you like?
# 2
# For Scoop: 1
# Which flavour would you like:vanila(1),strawberry(2),chocolate(3),caramel(4),mint(5),rainbow(6),coffee(7),bubble gum(8)
# 5
# $2.5
# For Scoop: 2
# Which flavour would you like:vanila(1),strawberry(2),chocolate(3),caramel(4),mint(5),rainbow(6),coffee(7),bubble gum(8)
# 6
# $3.0
# How many toppings would you like to have?
# 2
# For topping: 1
# Whice topping would you like:peanuts(1),caramal_souce(2),rainbow_sprinkles(3),peacan(4),chocolate_sprinkles(5)
# 3
# For topping: 2
# Whice topping would you like:peanuts(1),caramal_souce(2),rainbow_sprinkles(3),peacan(4),chocolate_sprinkles(5)
# 3
# Total icecreams:[1]
# ...
